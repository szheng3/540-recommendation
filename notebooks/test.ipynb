# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Code for testing recipes with labels df

# %%
df = pd.read_csv('../data/recipes_w_labels.csv')
df = df[['RecipeId', 'label_cooktime', 'label_ingredients']]

# %%
df.head()
# Out:
#    RecipeId  label_cooktime  label_ingredients
# 0       992             149               1101
# 1      4384             416               1095
# 2      4523             151                554
# 3      7435            1006                131
# 4        44             984                745

# %%
len(df)
# Out:
# 271674

# %%
reviews_df = pd.read_csv('../data/reviews.csv')
recipes_df = pd.read_csv('../data/recipes.csv')
data = pd.merge(reviews_df, recipes_df, on='RecipeId')

# %%
data.head()
# Out:
#    ReviewId  RecipeId  AuthorId_x       AuthorName_x  Rating  \
# 0         2       992        2008          gayg msft       5
# 1       250       992        4242            marie m       5
# 2    242612       992      205100         mommyoftwo       5
# 3    463486       992      559815  karen.nash-horton       4
# 4    643932       992      743849             NELady       5
#
#                                               Review         DateSubmitted  \
# 0       better than any you can get at a restaurant!  2000-01-25T21:44:00Z
# 1  my family loved these.  fresher than any bough...  2001-01-02T16:19:29Z
# 2  Wow!  Awesome - Awesome - Awesome!  And I don'...  2006-01-27T06:09:46Z
# 3  This is a good recipe. I much prefer the oven ...  2007-08-15T11:04:13Z
# 4  GREAT recipe!  I used fat free cream cheese, p...  2008-06-02T18:24:08Z
#
#            DateModified                     Name  AuthorId_y  ...  \
# 0  2000-01-25T21:44:00Z  Jalapeno Pepper Poppers        1545  ...
# 1  2001-01-02T16:19:29Z  Jalapeno Pepper Poppers        1545  ...
# 2  2006-01-27T06:09:46Z  Jalapeno Pepper Poppers        1545  ...
# 3  2007-08-15T11:04:13Z  Jalapeno Pepper Poppers        1545  ...
# 4  2008-06-02T18:24:08Z  Jalapeno Pepper Poppers        1545  ...
#
#   SaturatedFatContent CholesterolContent SodiumContent CarbohydrateContent  \
# 0                 4.9               23.7         172.5                 3.2
# 1                 4.9               23.7         172.5                 3.2
# 2                 4.9               23.7         172.5                 3.2
# 3                 4.9               23.7         172.5                 3.2
# 4                 4.9               23.7         172.5                 3.2
#
#   FiberContent SugarContent ProteinContent RecipeServings RecipeYield  \
# 0          0.6          0.9            4.3           24.0         NaN
# 1          0.6          0.9            4.3           24.0         NaN
# 2          0.6          0.9            4.3           24.0         NaN
# 3          0.6          0.9            4.3           24.0         NaN
# 4          0.6          0.9            4.3           24.0         NaN
#
#                                   RecipeInstructions
# 0  c("In a mixing bowl, combine cheeses, bacon an...
# 1  c("In a mixing bowl, combine cheeses, bacon an...
# 2  c("In a mixing bowl, combine cheeses, bacon an...
# 3  c("In a mixing bowl, combine cheeses, bacon an...
# 4  c("In a mixing bowl, combine cheeses, bacon an...
#
# [5 rows x 35 columns]

# %%
merged_df = pd.merge(data, df, on='RecipeId')

# %%
merged_df.head(10)
# Out:
#    ReviewId  RecipeId  AuthorId_x       AuthorName_x  Rating  \
# 0         2       992        2008          gayg msft       5
# 1       250       992        4242            marie m       5
# 2    242612       992      205100         mommyoftwo       5
# 3    463486       992      559815  karen.nash-horton       4
# 4    643932       992      743849             NELady       5
# 5    768046       992     1072593           gailanng       5
# 6    906390       992      145580        sue parenio       5
# 7    913294       992     1248818             Babbsy       5
# 8    992835       992      857489     bad kitty 1116       5
# 9   1049317       992      885673           tbeale20       5
#
#                                               Review         DateSubmitted  \
# 0       better than any you can get at a restaurant!  2000-01-25T21:44:00Z
# 1  my family loved these.  fresher than any bough...  2001-01-02T16:19:29Z
# 2  Wow!  Awesome - Awesome - Awesome!  And I don'...  2006-01-27T06:09:46Z
# 3  This is a good recipe. I much prefer the oven ...  2007-08-15T11:04:13Z
# 4  GREAT recipe!  I used fat free cream cheese, p...  2008-06-02T18:24:08Z
# 5  Ay Karumba!  I've made these for various socia...  2008-12-17T18:56:35Z
# 6  These are heaven (and thank you gail for the t...  2009-07-13T15:47:24Z
# 7  My guests popped these in their mouths and the...  2009-07-24T20:56:16Z
# 8  These are the best! They are so much better th...  2009-11-20T13:57:25Z
# 9  I have been making this recipe for years.  The...  2010-02-06T10:51:30Z
#
#            DateModified                     Name  AuthorId_y  ...  \
# 0  2000-01-25T21:44:00Z  Jalapeno Pepper Poppers        1545  ...
# 1  2001-01-02T16:19:29Z  Jalapeno Pepper Poppers        1545  ...
# 2  2006-01-27T06:09:46Z  Jalapeno Pepper Poppers        1545  ...
# 3  2007-08-15T11:04:13Z  Jalapeno Pepper Poppers        1545  ...
# 4  2008-06-02T18:24:08Z  Jalapeno Pepper Poppers        1545  ...
# 5  2008-12-17T18:56:35Z  Jalapeno Pepper Poppers        1545  ...
# 6  2009-07-13T15:47:24Z  Jalapeno Pepper Poppers        1545  ...
# 7  2009-07-24T20:56:16Z  Jalapeno Pepper Poppers        1545  ...
# 8  2009-11-20T13:57:25Z  Jalapeno Pepper Poppers        1545  ...
# 9  2010-02-06T10:51:30Z  Jalapeno Pepper Poppers        1545  ...
#
#   SodiumContent CarbohydrateContent FiberContent SugarContent ProteinContent  \
# 0         172.5                 3.2          0.6          0.9            4.3
# 1         172.5                 3.2          0.6          0.9            4.3
# 2         172.5                 3.2          0.6          0.9            4.3
# 3         172.5                 3.2          0.6          0.9            4.3
# 4         172.5                 3.2          0.6          0.9            4.3
# 5         172.5                 3.2          0.6          0.9            4.3
# 6         172.5                 3.2          0.6          0.9            4.3
# 7         172.5                 3.2          0.6          0.9            4.3
# 8         172.5                 3.2          0.6          0.9            4.3
# 9         172.5                 3.2          0.6          0.9            4.3
#
#   RecipeServings RecipeYield  \
# 0           24.0         NaN
# 1           24.0         NaN
# 2           24.0         NaN
# 3           24.0         NaN
# 4           24.0         NaN
# 5           24.0         NaN
# 6           24.0         NaN
# 7           24.0         NaN
# 8           24.0         NaN
# 9           24.0         NaN
#
#                                   RecipeInstructions label_cooktime  \
# 0  c("In a mixing bowl, combine cheeses, bacon an...            149
# 1  c("In a mixing bowl, combine cheeses, bacon an...            149
# 2  c("In a mixing bowl, combine cheeses, bacon an...            149
# 3  c("In a mixing bowl, combine cheeses, bacon an...            149
# 4  c("In a mixing bowl, combine cheeses, bacon an...            149
# 5  c("In a mixing bowl, combine cheeses, bacon an...            149
# 6  c("In a mixing bowl, combine cheeses, bacon an...            149
# 7  c("In a mixing bowl, combine cheeses, bacon an...            149
# 8  c("In a mixing bowl, combine cheeses, bacon an...            149
# 9  c("In a mixing bowl, combine cheeses, bacon an...            149
#
#   label_ingredients
# 0              1101
# 1              1101
# 2              1101
# 3              1101
# 4              1101
# 5              1101
# 6              1101
# 7              1101
# 8              1101
# 9              1101
#
# [10 rows x 37 columns]

# %%
len(merged_df)
# Out:
# 1401963

# %%
merged_df.columns
# Out:
# Index(['ReviewId', 'RecipeId', 'AuthorId_x', 'AuthorName_x', 'Rating',
#        'Review', 'DateSubmitted', 'DateModified', 'Name', 'AuthorId_y',
#        'AuthorName_y', 'CookTime', 'PrepTime', 'TotalTime', 'DatePublished',
#        'Description', 'Images', 'RecipeCategory', 'Keywords',
#        'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions', 'label_cooktime',
#        'label_ingredients'],
#       dtype='object')

# %%
merged_df['RecipeCategory'].unique()
# Out:
# array(['Vegetable', 'Weeknight', 'Chicken Breast', 'Meat', 'Chicken',
#        'Strawberry', 'Dessert', 'Lunch/Snacks', 'Lamb/Sheep', 'Steak',
#        'Cheese', 'Pork', 'Pie', 'Tuna', 'Beverages', 'Summer', 'Potato',
#        'Sauces', 'Breads', 'Whole Chicken', 'Quick Breads', 'Fruit',
#        'Thai', 'High In...', 'Chicken Livers', 'Drop Cookies', 'Winter',
#        'Bar Cookie', 'High Protein', 'Candy', 'Beans', 'Cheesecake',
#        'Meatloaf', 'Punch Beverage', 'Corn', 'Onions', 'Stew',
#        'Pineapple', 'Whole Turkey', 'German', 'Low Protein', 'Breakfast',
#        'Poultry', 'Penne', 'White Rice', '< 60 Mins', 'Lebanese', 'Crab',
#        'Tex Mex', 'Cauliflower', 'European', 'Ham', 'No Cook',
#        'Clear Soup', 'Lentil', 'Savory Pies', 'Yeast Breads', 'Chowders',
#        'Spaghetti', 'Smoothies', 'Free Of...', 'Apple', '< 15 Mins',
#        'Scones', 'Chinese', 'Christmas', 'Spreads', 'Salad Dressings',
#        'Gelatin', 'Cajun', 'Pears', 'Vietnamese', 'Beef Organ Meats',
#        'Asian', 'Crawfish', 'Berries', 'Soy/Tofu', 'One Dish Meal',
#        'Veal', 'Mussels', 'Orange Roughy', 'Low Cholesterol',
#        'Frozen Desserts', 'Roast Beef', 'Chicken Thigh & Leg',
#        'Long Grain Rice', 'Hungarian', '< 30 Mins', 'Oven', 'Lobster',
#        'Rice', 'Manicotti', 'Shakes', 'Brown Rice', 'Spanish', 'Halibut',
#        'Healthy', 'Rabbit', 'Greens', 'Potluck', 'Vegan',
#        'Very Low Carbs', 'Chutneys', 'Plums', 'Collard Greens',
#        'Kid Friendly', 'Mexican', 'Stocks', 'Black Beans', 'Jellies',
#        'Mahi Mahi', 'Lactose Free', 'Canadian', 'Southwestern U.S.',
#        'Short Grain Rice', 'Refrigerator', 'Grains', 'Scandinavian',
#        'Gumbo', 'Broil/Grill', 'Microwave', 'Native American',
#        'High Fiber', 'Dutch', 'Yam/Sweet Potato', 'Russian', 'Swedish',
#        'Raspberries', 'Spicy', 'Caribbean', 'Curries', 'Bass',
#        'Pasta Shells', 'African', 'Wild Game', 'Peppers', 'Greek',
#        'Citrus', 'Homeopathy/Remedies', 'Southwest Asia (middle East)',
#        'Bath/Beauty', 'Catfish', 'Melons', 'Indonesian', 'Coconut',
#        'Deer', 'Thanksgiving', 'Oranges', 'Spring', 'Japanese', 'Spinach',
#        'Tilapia', 'Squid', 'Australian', 'Household Cleaner', 'Polish',
#        'Whole Duck', '< 4 Hours', 'Trout', 'Bear', 'Colombian', 'Kosher',
#        'Cantonese', 'No Shell Fish', 'Sourdough Breads', 'Cuban',
#        'Medium Grain Rice', 'Hawaiian', 'Duck Breasts', 'Perch', 'Korean',
#        'Creole', 'Swiss', 'Moroccan', 'Sweet', 'Papaya', 'Szechuan',
#        'Turkey Breasts', 'Welsh', 'Austrian', 'Summer Dip', 'Pot Pie',
#        'Savory', 'Tropical Fruits', 'Tempeh', 'Roast', 'Egyptian',
#        'Polynesian', 'Cherries', 'Turkish', 'Tarts', 'Peanut Butter',
#        'Duck', 'Brunch', 'Lemon', 'Whitefish', 'Lime', 'Toddler Friendly',
#        'Chard', 'Mango', 'Scottish', 'Filipino', 'Costa Rican', 'Octopus',
#        'Brazilian', 'Mixer', 'New Zealand', "St. Patrick's Day",
#        'Camping', 'Danish', 'Elk', 'Ethiopian', 'Venezuelan', 'Belgian',
#        'Pheasant', 'Nuts', 'For Large Groups', nan, 'Quail', 'Nepalese',
#        'Canning', 'Egg Free', 'Easy', 'Dairy Free Foods', 'Portuguese',
#        'Halloween', 'Icelandic', 'Stove Top', 'Kiwifruit', 'Palestinian',
#        'Meatballs', 'Small Appliance', 'South African', 'Stir Fry',
#        'Beginner Cook', 'Georgian', 'Pakistani', 'Finnish', 'Norwegian',
#        'Chocolate Chip Cookies', 'South American', 'Puerto Rican',
#        'Chilean', 'Malaysian', 'Pressure Cooker', 'Moose', 'Goose',
#        'Nigerian', 'Iraqi', 'Bread Machine', 'Ecuadorean', 'Oysters',
#        'Dehydrator', 'Czech', 'Deep Fried', 'Pennsylvania Dutch',
#        'Mongolian', 'Cambodian', 'Bread Pudding', 'Breakfast Eggs',
#        'Sudanese', 'Spaghetti Sauce', 'Bean Soup', 'Peruvian', 'Steam',
#        'Inexpensive', 'Ham And Bean Soup', 'Oatmeal', 'Potato Soup',
#        'Desserts Fruit', 'Chicken Crock Pot', 'Pumpkin', 'Mushroom Soup',
#        'Mashed Potatoes', 'Avocado', 'Macaroni And Cheese', 'Artichoke',
#        'Indian', 'Ice Cream', 'Memorial Day', 'Grapes', 'Black Bean Soup',
#        'Somalian', 'Birthday', 'From Scratch', 'Guatemalan', 'Beef Liver',
#        'Hunan', 'Breakfast Casseroles', 'Snacks Sweet', 'Pot Roast'],
#       dtype=object)
